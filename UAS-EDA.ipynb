# %% [markdown]
# # UAS BIG DATA

# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('D:\Kulyeah\Semester 4\Big Data\YGO_Cards_v2.1.csv', encoding = "ISO-8859-1")

# %%
print(data)
# Out:
#                      Unnamed: 0 attack attribute defense  has_materials  \
# 0                3-Hump Lacooda    500     EARTH    1500          False
# 1      30,000-Year White Turtle   1250     WATER    2100          False
# 2     4-Starred Ladybug of Doom    800      WIND    1200          False
# 3                7 Colored Fish   1800     WATER     800          False
# 4              8-Claws Scorpion    300      DARK     200          False
# ...                         ...    ...       ...     ...            ...
# 5944           ZW - Phoenix Bow   1100      FIRE       0          False
# 5945         ZW - Sleipnir Mail   1000     LIGHT    1000          False
# 5946       ZW - Tornado Bringer   1300      WIND    1800          False
# 5947       ZW - Ultimate Shield      0     EARTH    2000          False
# 5948         ZW - Unicorn Spear   1900     LIGHT       0          False
#
#       has_name_condition  is_extra_deck  is_fusion  is_link  is_pendulum  ...  \
# ...

# %%
data.describe()
# Out:
#        link_number  pendulum_left  pendulum_right        stars
# count   107.000000     241.000000      241.000000  5836.000000
# mean      2.355140       4.385892        4.385892     4.470699
# std       0.792087       2.808552        2.808552     2.248488
# min       1.000000       0.000000        0.000000     1.000000
# 25%       2.000000       2.000000        2.000000     3.000000
# 50%       2.000000       4.000000        4.000000     4.000000
# 75%       3.000000       7.000000        7.000000     6.000000
# max       5.000000      13.000000       13.000000    12.000000

# %%
data.ffill()
# Out:
#                      Unnamed: 0 attack attribute defense  has_materials  \
# 0                3-Hump Lacooda    500     EARTH    1500          False
# 1      30,000-Year White Turtle   1250     WATER    2100          False
# 2     4-Starred Ladybug of Doom    800      WIND    1200          False
# 3                7 Colored Fish   1800     WATER     800          False
# 4              8-Claws Scorpion    300      DARK     200          False
# ...                         ...    ...       ...     ...            ...
# 5944           ZW - Phoenix Bow   1100      FIRE       0          False
# 5945         ZW - Sleipnir Mail   1000     LIGHT    1000          False
# 5946       ZW - Tornado Bringer   1300      WIND    1800          False
# 5947       ZW - Ultimate Shield      0     EARTH    2000          False
# 5948         ZW - Unicorn Spear   1900     LIGHT       0          False
#
#       has_name_condition  is_extra_deck  is_fusion  is_link  is_pendulum  ...  \
# ...

# %%
fig, ax = plt.subplots(figsize=(15,8))
ax.bar(data.Type[0:50], data.attribute[0:50], color="r")
plt.xticks(rotation=90)
plt.xlabel('Attribute', color="w")
plt.ylabel('Type', color="w")
plt.title('Sebaran', color="w")
plt.show()

# %%
print(data.attack[0:10])
# Out:
# 0     500
# 1    1250
# 2     800
# 3    1800
# 4     300
# 5     500
# 6    1600
# 7    1900
# 8     300
# 9    4000
# Name: attack, dtype: object

# %%
data.isna().sum()
# Out:
# Unnamed: 0               0
# attack                   0
# attribute                0
# defense                107
# has_materials            0
# has_name_condition       0
# is_extra_deck            0
# is_fusion                0
# is_link                  0
# is_pendulum              0
# is_synchro               0
# is_xyz                   0
# link_markers          5842
# link_number           5842
# materials             4919
# monster_types            0
# name_condition        5943
# number                  22
# pendulum_left         5708
# pendulum_right        5708
# pendulum_text         5709
# releases                 0
# Type                     0
# stars                  113
# text                    61
# dtype: int64

# %%
newData = data.dropna()
newData.isna().sum()
# Out:
# Unnamed: 0            0.0
# attack                0.0
# attribute             0.0
# defense               0.0
# has_materials         0.0
# has_name_condition    0.0
# is_extra_deck         0.0
# is_fusion             0.0
# is_link               0.0
# is_pendulum           0.0
# is_synchro            0.0
# is_xyz                0.0
# link_markers          0.0
# link_number           0.0
# materials             0.0
# monster_types         0.0
# name_condition        0.0
# number                0.0
# pendulum_left         0.0
# pendulum_right        0.0
# pendulum_text         0.0
# releases              0.0
# Type                  0.0
# stars                 0.0
# text                  0.0
# dtype: float64

# %%
fig, ax = plt.subplots(figsize =(15, 10))
 
ax.barh(data.Type[0:50], data.attribute[0:50],color="r")
 
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)

ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
 
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
 
ax.grid(visible = True, color ='black',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)
 
ax.invert_yaxis()
 
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='g')
 
ax.set_title('Sebaran',
             loc ='left', )

plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5949 entries, 0 to 5948
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          5949 non-null   object
#  1   attack              5949 non-null   object
#  2   attribute           5949 non-null   object
#  3   defense             5842 non-null   object
#  4   has_materials       5949 non-null   bool
#  5   has_name_condition  5949 non-null   bool
#  6   is_extra_deck       5949 non-null   bool
#  7   is_fusion           5949 non-null   bool
#  8   is_link             5949 non-null   bool
#  9   is_pendulum         5949 non-null   bool
#  10  is_synchro          5949 non-null   bool
#  11  is_xyz              5949 non-null   bool
#  12  link_markers        107 non-null    object
#  13  link_number         107 non-null    float64
#  14  materials           1030 non-null   object
#  15  monster_types       5949 non-null   object
# ...

# %%
fig, ax = plt.subplots(figsize=(15,10))
data.hist(ax=ax)
# Out:
# C:\Users\Aizu\AppData\Local\Temp\ipykernel_265992\3848413097.py:2: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   data.hist(ax=ax)
# array([[<AxesSubplot:title={'center':'link_number'}>,
#         <AxesSubplot:title={'center':'pendulum_left'}>],
#        [<AxesSubplot:title={'center':'pendulum_right'}>,
#         <AxesSubplot:title={'center':'stars'}>]], dtype=object)

# %%
fig, ax = plt.subplots(figsize=(15,10))
ax = sns.heatmap(data.corr(), vmin=-0.5, vmax=1.5, ax=ax)
